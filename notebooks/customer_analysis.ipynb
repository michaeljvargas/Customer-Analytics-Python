# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/transactions.csv")
df["transaction_date"] = pd.to_datetime(df["transaction_date"])
df.head()
# Out:
#    transaction_id customer_id transaction_date  amount     category
# 0               1        C001       2025-08-01   24.99    Groceries
# 1               2        C002       2025-08-02  120.50  Electronics
# 2               3        C001       2025-08-15   15.25       Coffee
# 3               4        C003       2025-08-20  220.00         Home
# 4               5        C004       2025-09-01   45.10    Groceries

# %%
monthly_revenue = (
    df.set_index("transaction_date")
      .resample("ME")["amount"]
      .sum()
)

# %%
monthly_revenue.plot(title="Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
customer_spend = (
    df.groupby("customer_id")["amount"]
      .sum()
      .sort_values(ascending=False)
)

customer_spend.head(10)
# Out:
# customer_id
# C003    239.99
# C001    180.24
# C002    155.50
# C005     89.99
# C004     45.10
# C006     12.75
# Name: amount, dtype: float64
